# %%
# Import Qiskit

from qiskit import QuantumCircuit as qct
from qiskit.quantum_info import Kraus, SuperOp
from qiskit.visualization import plot_histogram
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
from qiskit_aer import AerSimulator

from qiskit_aer.noise import NoiseModel
from qiskit import QuantumCircuit, transpile
from qiskit_aer import AerSimulator
from qiskit.visualization import plot_histogram
import datetime

# %%
# Qiskit Runtime imports
from qiskit_ibm_runtime import QiskitRuntimeService
from qiskit_ibm_runtime import EstimatorV2 as Estimator

# %%
import pathlib

# %%
import numpy as np
import matplotlib.pyplot as plt

import torch
from torch.autograd import Function
from torchvision import datasets, transforms
import torch.optim as optim
import torch.nn as nn
import torch.nn.functional as F

import qiskit
from qiskit.visualization import *

# %%
import seaborn as sns
from sklearn.svm import LinearSVC
from sklearn.svm import SVC
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import RandomForestClassifier
from joblib import Parallel,delayed
from sklearn import tree
from sklearn.base import clone 
from sklearn.linear_model import ElasticNet

# %%
import array
import numpy as np
import warnings
import scipy.sparse as sp
import itertools
import pandas

from sklearn.base import BaseEstimator, ClassifierMixin, clone, is_classifier
from sklearn.base import MultiOutputMixin
from sklearn.base import MetaEstimatorMixin, is_regressor
from sklearn.preprocessing import LabelBinarizer
from sklearn.metrics.pairwise import euclidean_distances
from sklearn.utils import check_random_state
from sklearn.utils.deprecation import deprecated
from sklearn.utils.validation import _num_samples
from sklearn.utils.validation import check_is_fitted
from sklearn.utils.validation import check_X_y, check_array
from sklearn.utils.validation import _deprecate_positional_args
from sklearn.utils.multiclass import (_check_partial_fit_first_call,
                               check_classification_targets,
                               _ovr_decision_function)
from sklearn.utils.metaestimators import _safe_split, available_if
from sklearn.exceptions import NotFittedError

from joblib import Parallel

import copy

# %%
from QDB_Python import noise_model_modified # import noise model leveraging csv files or quantum database generated before

# %%
import os, fnmatch
def find(pattern, path):
    for root, dirs, files in os.walk(path):
        for name in files:
            if fnmatch.fnmatch(name, pattern):
                result = os.path.join(root, name)
    return result

# %%
pwd
# Out:
# '/Users/sozo/Documents/Quantum-Digital-Twins'

# %%
new_dir_name = 'QuantumDatabase_v6' #choose your quantum database e.g., QuantumDatabase_v5 already generated and exist in the "QuantumDatabase" folder.
path = '/Users/sozo/Documents/Quantum-Digital-Twins/QuantumDatabase/' # insert a path you would like to store your quantum database
new_dir = pathlib.Path(path, new_dir_name)

# %%
ibmQname = '*sherbrooke*'

# %%
pattern = ibmQname+'thermal_relaxation_values.csv'
filename = find(pattern, new_dir)

# %%
colnamesv6 = ['T1', 'T2', 'Freqs']
GateThermalsv6 = pandas.read_csv(filename, names=colnamesv6)
GateThermalsv6
# Out:
#                 T1             T2     Freqs
# 0    363113.658458  178210.175102  4.635663
# 1    377191.226218  309131.831155  4.736297
# 2    287426.754982  185122.277294  4.819178
# 3    307724.399780  266545.204451  4.747182
# 4    390451.076395  386867.013747  4.787875
# ..             ...            ...       ...
# 122  239155.002387  351762.519117  4.731482
# 123  281769.628889  332924.498672  4.820644
# 124  276693.884186  225071.437472  4.881318
# 125  245759.724646   30958.204982  4.977356
# 126  169510.613955   79921.231498  4.831261
#
# [127 rows x 3 columns]

# %%
colnamesv5 = ['T1', 'T2', 'Freqs']
GateThermalsv5 = pandas.read_csv(filename, names=colnamesv5)
GateThermalsv5
# Out:
#                 T1             T2     Freqs
# 0    439140.298968  136616.020653  4.635663
# 1    407819.296765  286321.005438  4.736297
# 2    203381.975217  150166.164982  4.819178
# 3    344907.248694  243886.407361  4.747182
# 4    412514.169935  262283.774552  4.787875
# ..             ...            ...       ...
# 122  218167.249203  288679.645121  4.731482
# 123  232628.236758  187373.051981  4.820644
# 124  227290.969661  256593.808112  4.881318
# 125  179905.011563   29092.351302  4.977356
# 126  336355.483787   85468.057876  4.831261
#
# [127 rows x 3 columns]

# %%
colnamesv4 = ['T1', 'T2', 'Freqs']
GateThermalsv4 = pandas.read_csv(filename, names=colnamesv4)
GateThermalsv4
# Out:
#                 T1             T2     Freqs
# 0    439140.298968  225200.449602  4.635663
# 1    380505.832633  324963.362697  4.736297
# 2    274295.731511  168613.364009  4.819178
# 3    438343.216170  278408.845692  4.747182
# 4    434816.582986  298132.505950  4.787875
# ..             ...            ...       ...
# 122  239423.423551  336976.390830  4.731482
# 123  173767.352768  213308.909828  4.820644
# 124  206202.230519  209828.526173  4.881318
# 125  180026.452850   29788.870231  4.977356
# 126  283469.883008  105814.474168  4.831261
#
# [127 rows x 3 columns]

# %%
colnamesv3 = ['T1', 'T2', 'Freqs']
GateThermalsv3 = pandas.read_csv(filename, names=colnamesv3)
GateThermalsv3
# Out:
#                 T1             T2     Freqs
# 0    456685.148193  240264.929585  4.635663
# 1    413356.726645  288994.141815  4.736297
# 2    260638.247178  150963.585184  4.819178
# 3    328187.213486  288043.707988  4.747182
# 4    210407.879549  272741.787623  4.787875
# ..             ...            ...       ...
# 122  210479.692011  340834.952135  4.731482
# 123  201656.938496  220288.391845  4.820644
# 124  241507.503777  209169.506794  4.881318
# 125  188880.158981   34437.704239  4.977356
# 126  362036.235426   94888.926023  4.831261
#
# [127 rows x 3 columns]

# %%
colnamesv2 = ['T1', 'T2', 'Freqs']
GateThermalsv2 = pandas.read_csv(filename, names=colnamesv2)
GateThermalsv2
# Out:
#                 T1             T2     Freqs
# 0    353674.161072  244587.098565  4.635670
# 1    366961.839011  344997.391881  4.736292
# 2    194583.273304  185377.555860  4.819173
# 3    406141.782020  327144.108410  4.747185
# 4    380069.464235  421213.394672  4.787876
# ..             ...            ...       ...
# 122  198567.885052  355025.499660  4.731541
# 123  252056.903052  255040.329264  4.820637
# 124  302023.071233  220378.688928  4.881325
# 125   87634.131910   25004.974991  4.977358
# 126  225913.932661   93068.573944  4.831250
#
# [127 rows x 3 columns]

# %%
colnamesv1 = ['T1', 'T2', 'Freqs']
GateThermalsv1 = pandas.read_csv(filename, names=colnamesv1)
GateThermalsv1
# Out:
#                 T1             T2     Freqs
# 0    353851.803044  254375.400324  4.635669
# 1    356975.792628  251184.405290  4.736286
# 2    146962.486337  141721.323278  4.819171
# 3    420795.756502  301135.063673  4.747181
# 4    428834.582324  286991.362352  4.787879
# ..             ...            ...       ...
# 122  322297.249673  355447.567006  4.731540
# 123  278570.326106  278184.777440  4.820635
# 124  201214.284292  185802.997745  4.881322
# 125  109781.488309   41169.703872  4.977363
# 126  268871.092089   75973.125321  4.831250
#
# [127 rows x 3 columns]

# %%
new_dir_name = 'QuantumDatabase_v6' #choose your quantum database e.g., QuantumDatabase_v5 already generated and exist in the "QuantumDatabase" folder.
path = '/Users/sozo/Documents/Quantum-Digital-Twins/QuantumDatabase/' # insert a path you would like to store your quantum database
new_dir = pathlib.Path(path, new_dir_name)

# %%
pattern = ibmQname+'readout_error_values.csv'
filename = find(pattern, new_dir)

# %%
colnames = ['prob_meas1_prep0', 'prob_meas0_prep1']
GateReadoutsPDv1 = pandas.read_csv(filename, names=colnames)
GateReadoutsPDv1
# Out:
#      prob_meas1_prep0  prob_meas0_prep1
# 0              0.0014            0.0056
# 1              0.0040            0.0112
# 2              0.0276            0.0166
# 3              0.0054            0.0078
# 4              0.0118            0.0142
# ..                ...               ...
# 122            0.0066            0.0056
# 123            0.0038            0.0052
# 124            0.0022            0.0062
# 125            0.0082            0.0108
# 126            0.0364            0.0240
#
# [127 rows x 2 columns]

# %%
colnames = ['prob_meas1_prep0', 'prob_meas0_prep1']
GateReadoutsPDv2 = pandas.read_csv(filename, names=colnames)
GateReadoutsPDv2
# Out:
#      prob_meas1_prep0  prob_meas0_prep1
# 0              0.0062            0.0142
# 1              0.0190            0.0076
# 2              0.0336            0.0304
# 3              0.0064            0.0140
# 4              0.0124            0.0176
# ..                ...               ...
# 122            0.0030            0.0080
# 123            0.0050            0.0078
# 124            0.0030            0.0072
# 125            0.0116            0.0084
# 126            0.0232            0.0254
#
# [127 rows x 2 columns]

# %%
colnames = ['prob_meas1_prep0', 'prob_meas0_prep1']
GateReadoutsPDv3 = pandas.read_csv(filename, names=colnames)
GateReadoutsPDv3
# Out:
#      prob_meas1_prep0  prob_meas0_prep1
# 0              0.0054            0.0044
# 1              0.0082            0.0116
# 2              0.0288            0.0234
# 3              0.0066            0.0192
# 4              0.0136            0.0188
# ..                ...               ...
# 122            0.0024            0.0076
# 123            0.0030            0.0082
# 124            0.0030            0.0060
# 125            0.0044            0.0112
# 126            0.0318            0.0268
#
# [127 rows x 2 columns]

# %%
colnames = ['prob_meas1_prep0', 'prob_meas0_prep1']
GateReadoutsPDv4 = pandas.read_csv(filename, names=colnames)
GateReadoutsPDv4
# Out:
#      prob_meas1_prep0  prob_meas0_prep1
# 0              0.0024            0.0092
# 1              0.0086            0.0092
# 2              0.0256            0.0152
# 3              0.0076            0.0152
# 4              0.0192            0.0144
# ..                ...               ...
# 122            0.0052            0.0074
# 123            0.0046            0.0076
# 124            0.0020            0.0070
# 125            0.0032            0.0072
# 126            0.0196            0.0152
#
# [127 rows x 2 columns]

# %%
colnames = ['prob_meas1_prep0', 'prob_meas0_prep1']
GateReadoutsPDv5 = pandas.read_csv(filename, names=colnames)
GateReadoutsPDv5
# Out:
#      prob_meas1_prep0  prob_meas0_prep1
# 0              0.0038            0.0056
# 1              0.0070            0.0078
# 2              0.0316            0.0180
# 3              0.0030            0.0082
# 4              0.0162            0.0194
# ..                ...               ...
# 122            0.0040            0.0060
# 123            0.0036            0.0068
# 124            0.0024            0.0054
# 125            0.0034            0.0066
# 126            0.0228            0.0142
#
# [127 rows x 2 columns]

# %%
colnames = ['prob_meas1_prep0', 'prob_meas0_prep1']
GateReadoutsPDv6 = pandas.read_csv(filename, names=colnames)
GateReadoutsPDv6
# Out:
#      prob_meas1_prep0  prob_meas0_prep1
# 0              0.0048            0.0114
# 1              0.0158            0.0302
# 2              0.0174            0.0090
# 3              0.0054            0.0190
# 4              0.0372            0.0452
# ..                ...               ...
# 122            0.0038            0.0060
# 123            0.0028            0.0102
# 124            0.0026            0.0078
# 125            0.0094            0.0074
# 126            0.0136            0.0170
#
# [127 rows x 2 columns]

# %%
P1v1 = pandas.DataFrame(GateReadoutsPDv1['prob_meas1_prep0'])
P1v2 = pandas.DataFrame(GateReadoutsPDv2['prob_meas1_prep0'])
P1v3 = pandas.DataFrame(GateReadoutsPDv3['prob_meas1_prep0'])
P1v4 = pandas.DataFrame(GateReadoutsPDv4['prob_meas1_prep0'])
P1v5 = pandas.DataFrame(GateReadoutsPDv5['prob_meas1_prep0'])
P1v6 = pandas.DataFrame(GateReadoutsPDv6['prob_meas1_prep0'])

P2v1 = pandas.DataFrame(GateReadoutsPDv1['prob_meas0_prep1'])
P2v2 = pandas.DataFrame(GateReadoutsPDv2['prob_meas0_prep1'])
P2v3 = pandas.DataFrame(GateReadoutsPDv3['prob_meas0_prep1'])
P2v4 = pandas.DataFrame(GateReadoutsPDv4['prob_meas0_prep1'])
P2v5 = pandas.DataFrame(GateReadoutsPDv5['prob_meas0_prep1'])
P2v6 = pandas.DataFrame(GateReadoutsPDv6['prob_meas0_prep1'])

# %%
sns.histplot(data=P2v1, x="prob_meas0_prep1")
# Out:
# <Axes: xlabel='prob_meas0_prep1', ylabel='Count'>

# %%
sns.histplot(data=P2v2, x="prob_meas0_prep1")
# Out:
# <Axes: xlabel='prob_meas0_prep1', ylabel='Count'>

# %%
sns.histplot(data=P2v3, x="prob_meas0_prep1")
# Out:
# <Axes: xlabel='prob_meas0_prep1', ylabel='Count'>

# %%
sns.histplot(data=P2v4, x="prob_meas0_prep1")
# Out:
# <Axes: xlabel='prob_meas0_prep1', ylabel='Count'>

# %%
sns.histplot(data=P2v5, x="prob_meas0_prep1")
# Out:
# <Axes: xlabel='prob_meas0_prep1', ylabel='Count'>

# %%
sns.histplot(data=P2v6, x="prob_meas0_prep1")
# Out:
# <Axes: xlabel='prob_meas0_prep1', ylabel='Count'>

# %%
sns.histplot(data=P1v1, x="prob_meas1_prep0")
# Out:
# <Axes: xlabel='prob_meas1_prep0', ylabel='Count'>

# %%
sns.histplot(data=P1v2, x="prob_meas1_prep0")
# Out:
# <Axes: xlabel='prob_meas1_prep0', ylabel='Count'>

# %%
sns.histplot(data=P1v3, x="prob_meas1_prep0")
# Out:
# <Axes: xlabel='prob_meas1_prep0', ylabel='Count'>

# %%
sns.histplot(data=P1v4, x="prob_meas1_prep0")
# Out:
# <Axes: xlabel='prob_meas1_prep0', ylabel='Count'>

# %%
sns.histplot(data=P1v5, x="prob_meas1_prep0")
# Out:
# <Axes: xlabel='prob_meas1_prep0', ylabel='Count'>

# %%
sns.histplot(data=P1v6, x="prob_meas1_prep0")
# Out:
# <Axes: xlabel='prob_meas1_prep0', ylabel='Count'>

# %%
MeanP1 = (P1v1 + P1v2 + P1v3 + P1v4 + P1v5 + P1v6)/6
MeanP2 = (P2v1 + P2v2 + P2v3 + P2v4 + P2v5 + P2v6)/6

# %%
sns.histplot(data=MeanP1, x="prob_meas1_prep0")
# Out:
# <Axes: xlabel='prob_meas1_prep0', ylabel='Count'>

# %%
# use grid search cross-validation to optimize the bandwidth
params = {"bandwidth": np.logspace(-1, 1, 20)}
grid = GridSearchCV(KernelDensity(), params)
grid.fit(MeanP1)
# use the best estimator to compute the kernel density estimate
print("best bandwidth: {0}".format(grid.best_estimator_.bandwidth))
kde = grid.best_estimator_
# sample 126 new points from the data
new_P1 = kde.sample(127, random_state=0)

#colnames = ["prob_meas1_prep0"]
#new_P1 =  pandas.DataFrame(new_P1, columns = colnames)
# Out:
# best bandwidth: 0.1

# %%
# use grid search cross-validation to optimize the bandwidth
params = {"bandwidth": np.logspace(-1, 1, 20)}
grid = GridSearchCV(KernelDensity(), params)
grid.fit(MeanP2)
# use the best estimator to compute the kernel density estimate
print("best bandwidth: {0}".format(grid.best_estimator_.bandwidth))
kde = grid.best_estimator_
# sample 126 new points from the data
new_P2 = kde.sample(127, random_state=0)

#colnames = ["prob_meas0_prep1"]
#new_P2 =  pandas.DataFrame(new_P2, columns = colnames)
# Out:
# best bandwidth: 0.1

# %%
sns.displot(new_P2, x="prob_meas0_prep1", kind="kde")
# Out:
# /Users/sozo/miniforge3/envs/cirqenv/lib/python3.9/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(new_P1, x="prob_meas1_prep0", kind="kde", bw_adjust=0.1)
# Out:
# /Users/sozo/miniforge3/envs/cirqenv/lib/python3.9/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(new_P1, x="prob_meas1_prep0", kind="kde")
# Out:
# /Users/sozo/miniforge3/envs/cirqenv/lib/python3.9/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(MeanP1, x="prob_meas1_prep0", kind="kde", bw_adjust=0.1)
# Out:
# /Users/sozo/miniforge3/envs/cirqenv/lib/python3.9/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(MeanP1, x="prob_meas1_prep0", kind="kde")
# Out:
# /Users/sozo/miniforge3/envs/cirqenv/lib/python3.9/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
T1v1 = pandas.DataFrame(GateThermalsv1['T1'])
T1v2 = pandas.DataFrame(GateThermalsv2['T1'])
T1v3 = pandas.DataFrame(GateThermalsv3['T1'])
T1v4 = pandas.DataFrame(GateThermalsv4['T1'])
T1v5 = pandas.DataFrame(GateThermalsv5['T1'])
T1v6 = pandas.DataFrame(GateThermalsv6['T1'])

T2v1 = pandas.DataFrame(GateThermalsv1['T2'])
T2v2 = pandas.DataFrame(GateThermalsv2['T2'])
T2v3 = pandas.DataFrame(GateThermalsv3['T2'])
T2v4 = pandas.DataFrame(GateThermalsv4['T2'])
T2v5 = pandas.DataFrame(GateThermalsv5['T2'])
T2v6 = pandas.DataFrame(GateThermalsv6['T2'])

Freqsv1 = pandas.DataFrame(GateThermalsv1['Freqs'])
Freqsv2 = pandas.DataFrame(GateThermalsv2['Freqs'])
Freqsv3 = pandas.DataFrame(GateThermalsv3['Freqs'])
Freqsv4 = pandas.DataFrame(GateThermalsv4['Freqs'])
Freqsv5 = pandas.DataFrame(GateThermalsv5['Freqs'])
Freqsv6 = pandas.DataFrame(GateThermalsv6['Freqs'])

# %%
T1v1.min()
# Out:
# T1    12243.403065
# dtype: float64

# %%
MeanT1 = (T1v1 + T1v2 + T1v3 + T1v4 + T1v5 + T1v6)/6
MeanT2 = (T2v1 + T2v2 + T2v3 + T2v4 + T2v5 + T2v6)/6
MeanFreq = (Freqsv1 + Freqsv2 + Freqsv3 + Freqsv4 + Freqsv5 + Freqsv6)/6

# %%
MeanT1.min()
# Out:
# T1    70142.184024
# dtype: float64

# %%
from sklearn.neighbors import KernelDensity
from sklearn.model_selection import GridSearchCV
from sklearn.decomposition import PCA

# %% [markdown]
# # T1: kernel density estimate

# %%
# use grid search cross-validation to optimize the bandwidth
params = {"bandwidth": np.logspace(-1, 1, 20)}
grid = GridSearchCV(KernelDensity(), params)
grid.fit(MeanT1)
# use the best estimator to compute the kernel density estimate
print("best bandwidth: {0}".format(grid.best_estimator_.bandwidth))
kde = grid.best_estimator_
# sample 126 new points from the data
new_T1 = kde.sample(127, random_state=0)
# Out:
# best bandwidth: 10.0

# %% [markdown]
# # T2: kernel density estimate

# %%
# use grid search cross-validation to optimize the bandwidth
params = {"bandwidth": np.logspace(-1, 1, 20)}
grid = GridSearchCV(KernelDensity(), params)
grid.fit(MeanT2)
# use the best estimator to compute the kernel density estimate
print("best bandwidth: {0}".format(grid.best_estimator_.bandwidth))
kde = grid.best_estimator_
# sample 126 new points from the data
new_T2 = kde.sample(127, random_state=0)
# Out:
# best bandwidth: 10.0

# %% [markdown]
# # Freqs: kernel density estimate

# %%
# use grid search cross-validation to optimize the bandwidth
params = {"bandwidth": np.logspace(-1, 1, 20)}
grid = GridSearchCV(KernelDensity(), params)
grid.fit(MeanFreq)
# use the best estimator to compute the kernel density estimate
print("best bandwidth: {0}".format(grid.best_estimator_.bandwidth))
kde = grid.best_estimator_
# sample 126 new points from the data
new_Freqs = kde.sample(127, random_state=0)
# Out:
# best bandwidth: 0.1

# %% [markdown]
# # New Quantum Database

# %%
newData = np.concatenate((new_T1, new_T2), axis=1)

# %%
colnames = ['T1', 'T2']
GateThermals = pandas.DataFrame(newData, columns = colnames)
GateThermals
# Out:
#                 T1             T2
# 0    207523.261222   16935.052470
# 1    268319.643908  229565.410338
# 2    234708.178998   52542.768508
# 3    207498.051948   16909.843197
# 4    275647.245852  257964.954390
# ..             ...            ...
# 122  237979.160952   90896.738973
# 123  189372.194192  117836.527136
# 124  275660.233822  257977.942361
# 125  286368.974893  208217.721892
# 126  227881.915129  163661.215475
#
# [127 rows x 2 columns]

# %%
pwd
# Out:
# '/Users/sozo/Documents/Quantum-Digital-Twins'

# %%
GateThermals.to_csv('/Users/sozo/Documents/Quantum-Digital-Twins/QuantumDatabase/QuantumDatabase_sherbrooke_calibrated/ibm_sherbrooke_21-08-2024-19-30-30_thermal_relaxation_values.csv', index=False, header=False)

# %%
IBM_fez = pandas.read_csv('/Users/sozo/Documents/Quantum-Digital-Twins/QuantumDatabase/QuantumDatabase_sherbrooke_calibrated/ibm_fez_calibrations_2024-08-21T17_15_19Z.csv')
IBM_fez
# Out:
#      Qubit     T1 (us)     T2 (us)  Frequency (GHz)  Anharmonicity (GHz)  \
# 0        0  136.702222   85.612369                0                    0
# 1        1  130.777464  195.136045                0                    0
# 2        2   58.732562  120.247517                0                    0
# 3        3  156.196903  274.097106                0                    0
# 4        4  189.337223  112.924687                0                    0
# ..     ...         ...         ...              ...                  ...
# 151    151   82.278756  136.595862                0                    0
# 152    152  146.645519  229.594095                0                    0
# 153    153   31.122739   31.925842                0                    0
# 154    154  160.853189   92.943584                0                    0
# 155    155  125.020770   17.060424                0                    0
#
#      Readout assignment error   Prob meas0 prep1   Prob meas1 prep0   \
# ...

# %%
IBM_fez.keys()
# Out:
# Index(['Qubit', 'T1 (us)', 'T2 (us)', 'Frequency (GHz)', 'Anharmonicity (GHz)',
#        'Readout assignment error ', 'Prob meas0 prep1 ', 'Prob meas1 prep0 ',
#        'Readout length (ns)', 'ID error ', 'Z-axis rotation (rz) error ',
#        '√x (sx) error ', 'Pauli-X error ', 'CZ error ', 'Gate time (ns)',
#        'Operational'],
#       dtype='object')

# %%
sns.histplot(data=IBM_fez, x='Prob meas1 prep0 ')
# Out:
# <Axes: xlabel='Prob meas1 prep0 ', ylabel='Count'>

# %%
sns.histplot(data=IBM_fez, x='Prob meas0 prep1 ')
# Out:
# <Axes: xlabel='Prob meas0 prep1 ', ylabel='Count'>

# %%
new_P1 = IBM_fez['Prob meas1 prep0 ']
new_P2 = IBM_fez['Prob meas0 prep1 ']

# %%
new_P2[:127].values.shape
# Out:
# (127,)

# %%
newP = np.concatenate((new_P1[:127].values.reshape(127,1), new_P2[:127].values.reshape(127,1)), axis=1)

# %%
colnames = ['prob_meas1_prep0', 'prob_meas0_prep1']
GateReadoutsPD = pandas.DataFrame(newP, columns=colnames)
GateReadoutsPD
# Out:
#      prob_meas1_prep0  prob_meas0_prep1
# 0              0.0048            0.0072
# 1              0.0266            0.0384
# 2              0.0232            0.0212
# 3              0.0334            0.0278
# 4              0.0014            0.0078
# ..                ...               ...
# 122            0.0216            0.0304
# 123            0.0110            0.0130
# 124            0.0030            0.0098
# 125            0.0020            0.0114
# 126            0.0050            0.0136
#
# [127 rows x 2 columns]

# %%
GateReadoutsPD.to_csv('/Users/sozo/Documents/Quantum-Digital-Twins/QuantumDatabase/QuantumDatabase_sherbrooke_calibrated/ibm_sherbrooke_21-08-2024-19-30-30_readout_error_values.csv', index=False, header=False)

# %%
sns.histplot(data=GateThermals, x="T1")
# Out:
# <Axes: xlabel='T1', ylabel='Count'>

# %%
sns.histplot(data=GateThermals, x="T2")
# Out:
# <Axes: xlabel='T2', ylabel='Count'>

# %%
sns.histplot(data=GateThermals, x="Freqs")
# Out:
# <Axes: xlabel='Freqs', ylabel='Count'>

# %%
sns.histplot(data=MeanFreq, x="Freqs")
# Out:
# <Axes: xlabel='Freqs', ylabel='Count'>

# %%
colnames = ["Freqs"]
new_freqs =  pandas.DataFrame(new_Freqs, columns = colnames)

sns.displot(new_freqs, x="Freqs", kind="kde")
# Out:
# /Users/sozo/miniforge3/envs/cirqenv/lib/python3.9/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(MeanFreq, x="Freqs", kind="kde")
# Out:
# /Users/sozo/miniforge3/envs/cirqenv/lib/python3.9/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.histplot(data=Freqsv1, x="Freqs", kde = True)
# Out:
# <Axes: xlabel='Freqs', ylabel='Count'>

# %%
sns.histplot(data=Freqsv2, x="Freqs", kde = True)
# Out:
# <Axes: xlabel='Freqs', ylabel='Count'>

# %%
sns.histplot(data=Freqsv3, x="Freqs", kde = True)
# Out:
# <Axes: xlabel='Freqs', ylabel='Count'>

# %%
sns.histplot(data=Freqsv4, x="Freqs", kde = True)
# Out:
# <Axes: xlabel='Freqs', ylabel='Count'>

# %%
sns.histplot(data=Freqsv5, x="Freqs", kde = True)
# Out:
# <Axes: xlabel='Freqs', ylabel='Count'>

# %%
sns.histplot(data=Freqsv6, x="Freqs", kde = True)
# Out:
# <Axes: xlabel='Freqs', ylabel='Count'>

# %%
sns.histplot(data=Freqsv1, x="Freqs", kde = True)
sns.histplot(data=Freqsv2, x="Freqs", kde = True)
sns.histplot(data=Freqsv3, x="Freqs", kde = True)
sns.histplot(data=Freqsv4, x="Freqs", kde = True)
sns.histplot(data=Freqsv5, x="Freqs", kde = True)
sns.histplot(data=Freqsv6, x="Freqs", kde = True)
# Out:
# <Axes: xlabel='Freqs', ylabel='Count'>

# %%
sns.histplot(data=MeanT2, x="T2")
# Out:
# <Axes: xlabel='T2', ylabel='Count'>

# %%
sns.displot(MeanT2, x="T2", kind="kde", bw_adjust=10)
# Out:
# /Users/sozo/miniforge3/envs/cirqenv/lib/python3.9/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
fig, axs = plt.subplots(ncols=2)
sns.displot(GateThermals, x="T1", kind="kde", bw_adjust=10)
sns.displot(GateThermals, x="T2", kind="kde", bw_adjust=10)
# Out:
# /Users/sozo/miniforge3/envs/cirqenv/lib/python3.9/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /Users/sozo/miniforge3/envs/cirqenv/lib/python3.9/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(GateThermals, x="T2", kind="kde", bw_adjust=10)#new_T1, 
plt.savefig("T2.pdf", format='pdf')
# Out:
# /Users/sozo/miniforge3/envs/cirqenv/lib/python3.9/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(GateThermals, x="T1", kind="kde", bw_adjust=10)
plt.savefig("T1.pdf", format='pdf')
# Out:
# /Users/sozo/miniforge3/envs/cirqenv/lib/python3.9/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.histplot(data=MeanT2, x="T2", kde = True)
# Out:
# <Axes: xlabel='T2', ylabel='Count'>

# %%
sns.histplot(data=T2v1, x="T2")
sns.histplot(data=T2v2, x="T2")
sns.histplot(data=T2v3, x="T2")
sns.histplot(data=T2v4, x="T2")
sns.histplot(data=T2v5, x="T2")
sns.histplot(data=T2v6, x="T2")
# Out:
# <Axes: xlabel='T2', ylabel='Count'>

# %%
sns.histplot(data=T2v1, x="T2", kde = True)
# Out:
# <Axes: xlabel='T2', ylabel='Count'>

# %%
sns.histplot(data=T2v2, x="T2", kde = True)
# Out:
# <Axes: xlabel='T2', ylabel='Count'>

# %%
sns.histplot(data=T2v3, x="T2", kde = True)
# Out:
# <Axes: xlabel='T2', ylabel='Count'>

# %%
sns.histplot(data=T2v4, x="T2", kde = True)
# Out:
# <Axes: xlabel='T2', ylabel='Count'>

# %%
sns.histplot(data=T2v5, x="T2", kde = True)
# Out:
# <Axes: xlabel='T2', ylabel='Count'>

# %%
sns.histplot(data=T2v6, x="T2", kde = True)
# Out:
# <Axes: xlabel='T2', ylabel='Count'>

# %%
sns.histplot(data=MeanT1, x="T1")
# Out:
# <Axes: xlabel='T1', ylabel='Count'>

# %%
sns.displot(MeanT1, x="T1", kind="kde", bw_adjust=10)
# Out:
# /Users/sozo/miniforge3/envs/cirqenv/lib/python3.9/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(MeanT1, x="T1", kind="kde")
# Out:
# /Users/sozo/miniforge3/envs/cirqenv/lib/python3.9/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.histplot(data=MeanT1, x="T1", kde = True)
# Out:
# <Axes: xlabel='T1', ylabel='Count'>

# %%
sns.histplot(data=MeanT1, x="T1", kde = True, kde_kws = {'bw_adjust':1.5})
# Out:
# <Axes: xlabel='T1', ylabel='Count'>

# %%
sns.histplot(data=T1v1, x="T1")
sns.histplot(data=T1v2, x="T1")
sns.histplot(data=T1v3, x="T1")
sns.histplot(data=T1v4, x="T1")
sns.histplot(data=T1v5, x="T1")
sns.histplot(data=T1v6, x="T1")
# Out:
# <Axes: xlabel='T1', ylabel='Count'>

# %%
sns.histplot(data=T1v1, x="T1", kde = True)
sns.histplot(data=T1v2, x="T1", kde = True)
sns.histplot(data=T1v3, x="T1", kde = True)
sns.histplot(data=T1v4, x="T1", kde = True)
sns.histplot(data=T1v5, x="T1", kde = True)
sns.histplot(data=T1v6, x="T1", kde = True)
# Out:
# <Axes: xlabel='T1', ylabel='Count'>

# %%
sns.histplot(data=T1v1, x="T1", kde = True)
# Out:
# <Axes: xlabel='T1', ylabel='Count'>

# %%
sns.histplot(data=T1v2, x="T1", kde = True)
# Out:
# <Axes: xlabel='T1', ylabel='Count'>

# %%
sns.histplot(data=T1v3, x="T1", kde = True)
# Out:
# <Axes: xlabel='T1', ylabel='Count'>

# %%
sns.histplot(data=T1v4, x="T1", kde = True)
# Out:
# <Axes: xlabel='T1', ylabel='Count'>

# %%
sns.histplot(data=T1v5, x="T1", kde = True)
# Out:
# <Axes: xlabel='T1', ylabel='Count'>

# %%
sns.histplot(data=T1v6, x="T1", kde = True)
# Out:
# <Axes: xlabel='T1', ylabel='Count'>

# %%
T1v1
# Out:
# 0      353851.803044
# 1      356975.792628
# 2      146962.486337
# 3      420795.756502
# 4      428834.582324
#            ...
# 122    322297.249673
# 123    278570.326106
# 124    201214.284292
# 125    109781.488309
# 126    268871.092089
# Name: T1, Length: 127, dtype: float64

# %%
ibmQname = '*sherbrooke*' # it can be *kyoto*, *osaka*, or *brisbane*
path = '/Users/sozo/Documents/Quantum-Digital-Twins/QuantumDatabase/'

noise_model = noise_model_modified.NoiseModel.from_backend(
    gate_error=True,
    readout_error=True,
    thermal_relaxation=True,
    temperature=0,
    gate_lengths=True,
    gate_length_units="ns",
    warnings=None,
    path = path,
    ibmname = ibmQname
)
# Out:
# /Users/sozo/Documents/Quantum-Digital-Twins/QDB_Python/noise_model_modified.py:359: UserWarning: When a BackendV2 is supplied, `warnings` are ignored, and their default values are used.
#   warn(
